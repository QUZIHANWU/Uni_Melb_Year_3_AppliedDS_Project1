# %%
import pandas as pd
data = pd.read_csv('clf_1.csv')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 9))

for i in range(6):
    plt.subplot(321+i)
    plt.plot(data.loc[i*100:100+i*100, ['true']], label='true')
    plt.plot(data.loc[i*100:100+i*100, ['pred']], label='pred')
    plt.xlabel('Time', size=16)
    plt.ylabel('total amount', size=16)
    plt.xticks(size=16)
    plt.yticks(size=16)
    plt.legend()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                wspace=None, hspace=0.5)
plt.savefig('clf_1_duibi.png')

# %%
import pandas as pd
data = pd.read_csv('clf_1.csv')

# %%
data_1 = pd.read_csv('lr_1.csv')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 9))

for i in range(6):
    plt.subplot(321+i)
    plt.plot(data.loc[i*100:100+i*100, ['true']], label='true')
    plt.plot(data.loc[i*100:100+i*100, ['pred']], label='lr_pred', c='r')
    plt.plot(data_1.loc[i*100:100+i*100, ['pred']], label='dt_pred', c='g')
    plt.xlabel('Time', size=16)
    plt.ylabel('total amount', size=16)
    plt.xticks(size=16)
    plt.yticks(size=16)
    plt.legend()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                wspace=None, hspace=0.5)
plt.savefig('lr_clf_1_duibi.png')
